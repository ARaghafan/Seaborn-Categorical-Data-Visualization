# %% [markdown]
# ![Seaborn Intro](Seabornint.jpg)
# # Seaborn Categorical Data Visualization
#
# ## 1. Introduction
#
# **What is this topic about?**
# Categorical data visualization is about representing data where the values are not numbers but categories, like gender, product type, or city. Seaborn, a Python visualization library built on top of Matplotlib, makes it very easy to create attractive and informative plots for such data.
#
# **Short overview in my own words:**
# Instead of dealing with numbers like “heights in centimeters,” categorical visualization focuses on groups like “male vs female” or “apples vs oranges.” Seaborn provides special plots—like bar plots, count plots, box plots, and violin plots—that help us understand differences between these categories.
#
# **Real-life examples:**
# - Comparing sales of different product types in a store (electronics vs clothing vs food).
# - Visualizing survey responses like “satisfied, neutral, dissatisfied.”
# - Comparing average salaries across different professions.
#
# ---
#
# ## 2. Theoretical Background
#
# **Definition of categorical data:**
# Categorical data represents information that can be divided into groups or categories. Unlike numerical data, it doesn’t make sense to calculate things like averages directly (e.g., you can’t average “male” and “female”).
#
# **Why visualize categorical data?**
# Because it helps us quickly see patterns, trends, and differences between groups. For example, a bar plot can show which category is more frequent, while a box plot can show how numerical values vary across categories.
#
# **Key Seaborn functions for categorical plots:**
# - `sns.barplot()` → shows average values per category.
# - `sns.countplot()` → shows counts of each category.
# - `sns.boxplot()` → shows distribution (median, quartiles, outliers).
# - `sns.violinplot()` → similar to boxplot but adds density information.
# - `sns.stripplot()` and `sns.swarmplot()` → show individual data points within categories.
#
# **Mini-theory of bar plots (example):**
# - X-axis → categories (like "male" and "female").
# - Y-axis → numerical values (like average income).
# - Bars show the mean value for each category, with optional error bars (confidence intervals).
#
# **About the library (Seaborn):**
# Seaborn is built on top of Matplotlib but is designed for statistical graphics. It automatically calculates things like averages, error bars, and density estimates for categorical data. This makes it easier and faster to visualize data without writing a lot of code.
#
# **Code introduction (no run yet, just explanation):**
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# ```
# ![Seaborn Intro](Plotex1.png)

# %% [markdown]
# <img src="pinx.png" align="right" width="400"/>
# # 🐧 Penguins Dataset Story
#
# Welcome to Antarctica — cold, windy, and home to some of the most fashionable birds on Earth: **penguins**.
# In this dataset, we’re basically the penguin paparazzi.
#
# We measured their **flippers** (because who doesn’t want to know the wingspan of a flightless bird?),
# their **bills** (think of it as penguin nose jobs),
# and their **weight** (yes, some penguins might need a gym membership).
#
# We also noted their **species**:
# - **Adelie** → the classic tuxedo penguin.
# - **Gentoo** → the speed demons of the penguin world.
# - **Chinstrap** → the ones that look like they’re wearing little penguin helmets.
# <img src="ping1.png" align="right" width="400"/>
#
# And of course, their **island homes**: Biscoe, Dream, or Torgersen — basically penguin Airbnb locations.
#
# So what’s the point? With this dataset we can answer burning questions like:
# - Do boy penguins actually weigh more, or is that just bravado?
# - Which species has the biggest “flipper flex”?
# - Do some islands secretly host penguin giants?
#
# In short: this dataset is penguin reality TV, and Seaborn lets us binge-watch the drama in colorful plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Penguins Dataset¶

# %%
penguins = sns.load_dataset("penguins")
print("\n" + "="*60)
print(penguins.info())
print("="*60)
print(penguins.duplicated())
print("="*60)
print(penguins[penguins.isna().all(axis=1)])
print("="*60)
penguins.isna().sum()
# Out:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# None
# ...
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool
# ...
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex]
# Index: []
# ...
# species               0
# island                0
# ...

# %% [markdown]
# #  1. CountPlot — Frequency of Categories
# ### Shows category counts and gender distribution — simple but impactful
# show how many penguins belong to each species.

# %%
sns.set(style="whitegrid", palette="muted")
plt.figure(figsize=(8,5))
sns.countplot(x="species", data=penguins, hue="island")
plt.title("Number of Penguins by Species and Sex")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #  2. BoxPlot — Compare numerical distributions by category
# ### How a numerical variable varies across categorical groups.
# ### → Gentoo penguins tend to have longer flippers.

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="species", y="flipper_length_mm", hue="sex", data=penguins, palette="Set2")
plt.title("Flipper Length by Penguin Species and Sex")
plt.xlabel("Species")
plt.ylabel("Flipper Length (mm)")
plt.show()

# %% [markdown]
# #  3. ViolinPlot — Visualize shape of distribution
# ### Combines boxplot + density curve = visually rich & easy to explain.

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x="species", y="bill_depth_mm", hue="sex", data=penguins, split=True, palette="coolwarm")
plt.title("Body Mass Distribution by Penguin Species and Sex")
plt.xlabel("Species")
plt.ylabel("Body Mass (g)")
plt.show()

# %% [markdown]
# #  4. SwarmPlot — Show individual observations
# ### Each dot = a penguin → great to show real variability.

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(x="species", y="bill_length_mm", hue="sex", data=penguins, dodge=True)
plt.title("Bill Length by Species (individual observations)")
plt.xlabel("Species")
plt.ylabel("Bill Length (mm)")
plt.show()

# %% [markdown]
# #  5. CatPlot — Combine everything easily
# ### Multiple subplots in one command
#
# ### Compact, clear, and perfect for storytelling

# %%
sns.catplot(
    x="species",
    y="bill_depth_mm",
    hue="sex",
    col="island",
    kind="box",
    data=penguins,
    height=5,
    aspect=0.8
)
plt.subplots_adjust(top=0.8)
plt.suptitle("Bill Depth by Species, Sex, and Island")
plt.show()

# %% [markdown]
# #  🐧 6. Pairing Categorical and Numerical
# ###  Great for your presentation’s finale — colorful, multi-variable overview.

# %%
sns.pairplot(penguins, hue="species", diag_kind="kde", palette="husl")
plt.suptitle("Pairwise Relationships between Penguin Features", y=1.02)
plt.show()

# %% [markdown]
# #  7. Barplot — Show average values by category
# ### By default, sns.barplot() shows the mean of a numeric variable per category.
# ### Great to explain “central tendency” — i.e., which species are heavier on average.

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="species", y="body_mass_g", hue="sex", data=penguins, palette="viridis")
plt.title("Average Body Mass by Species and Sex")
plt.xlabel("Species")
plt.ylabel("Mean Body Mass (g)")
plt.show()

# %% [markdown]
# #  8. PointPlot — Trend or comparison across categories
# ### pointplot() adds confidence intervals and shows trends clearly.
# ### Why it’s impressive: It looks professional — great for showing patterns or differences between groups.

# %%
plt.figure(figsize=(8,6))
sns.pointplot(x="island", y="flipper_length_mm", hue="sex", data=penguins, palette="coolwarm", dodge=True)
plt.title("Average Flipper Length across Islands by Sex")
plt.xlabel("Island")
plt.ylabel("Mean Flipper Length (mm)")
plt.show()

# %% [markdown]
# #  9. StripPlot — Simpler version of swarmplot (faster)
# ### It’s like swarmplot but without collision avoidance — quicker for big datasets.
# ###  Use this when: You want to show individual data points but keep it simple

# %%
plt.figure(figsize=(8,6))
sns.stripplot(x="species", y="body_mass_g", hue="sex", data=penguins, jitter=True, alpha=0.7, palette="Set1")
plt.title("Body Mass by Species and Sex (Strip Plot)")
plt.xlabel("Species")
plt.ylabel("Body Mass (g)")
plt.show()

# %% [markdown]
# #  10. BoxenPlot — Advanced alternative to boxplot
#
# ### Boxen plots show distributional shape for large datasets — more quantiles than boxplot.
# ###  Why use it: It’s visually richer and rarely shown — will impress your classmates!

# %%
plt.figure(figsize=(8,6))
sns.boxenplot(x="species", y="body_mass_g", hue="sex", data=penguins, palette="cubehelix")
plt.title("Body Mass Distribution by Species and Sex (Boxen Plot)")
plt.xlabel("Species")
plt.ylabel("Body Mass (g)")
plt.show()

# %% [markdown]
# #  11. CatPlot (violin type) — quick grid visualization
#
# ### You can use sns.catplot() with different kind arguments (box, violin, bar, etc.):
# ###  This is perfect for multi-category comparisons.

# %%
sns.catplot(
    x="species",
    y="bill_length_mm",
    hue="sex",
    col="island",
    kind="violin",
    data=penguins,
    height=5,
    aspect=0.8,
    palette="muted"
)
plt.subplots_adjust(top=0.8)
plt.suptitle("Bill Length by Species, Sex, and Island (Violin CatPlot)")
plt.show()

# %% [markdown]
# #  12. Countplot with multiple categories
#
# ### If you want a clean frequency plot (like a histogram for categorical data):
# ###  Why it’s strong: Everyone immediately understands counts and group differences.

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="island", hue="species", data=penguins, palette="pastel")
plt.title("Penguin Species Distribution across Islands")
plt.xlabel("Island")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 🎉 Closing
#
# This brings us to the end of our journey with the **funny penguins** and their fascinating data 🐧📊.
# We’ve seen how simple numbers can turn into **colorful stories and visual insights** with Seaborn.
#
# ✨ Thank you all for your attention,
# and I hope you enjoyed exploring the penguins as much as I did! 🐧💙
#
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⣀⢠⡤⠤⠖⠒⠒⠒⠲⣆⠀⠀⠀⠀⣾⠋⠉⠉⠛⢷⠀⣴⠖⠒⠤⣄⠀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⠤⠶⢺⣾⣏⠁⠀⠀⣧⣼⣇⣀⠀⠀⠀⡀⠀⠘⡆⠀⠀⢰⣏⠀⠀⠀⠀⠘⣿⡟⠀⠀⢠⢃⣼⡏⠉⠙⢳⡆⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⣀⡤⠴⠒⠋⠙⣇⣿⠀⠀⠀⣿⣿⠀⠀⠀⢸⣿⣿⣿⠃⠀⢰⣿⡀⠀⠹⡄⠀⢸⣿⠀⠀⠀⠀⠀⢹⡇⠀⠀⢸⡿⣽⠀⠀⠀⡜⠀⣀⡤⠖⠓⠢⢤⣀⠀
# ⣠⡴⠒⠉⠁⠀⠀⠀⠀⠀⠸⣿⡇⠀⠀⠘⠛⠃⠀⠀⠈⡟⠉⣿⠀⠀⠘⠛⠃⠀⠀⢷⠀⢸⣿⠀⠀⢠⡀⠀⠀⠀⠀⠀⣿⢧⡇⠀⠀⠸⠗⠚⠁⠀⠀⠀⣀⣠⣾⠃
# ⣿⡇⠀⠀⠀⠀⠀⠀⣶⣶⣿⢿⢹⠀⠀⠀⢀⣀⠀⠀⠀⢳⠀⣿⠀⠀⢀⣀⣤⠀⠀⠘⣇⢸⡏⠀⠀⢸⣧⠀⠀⠀⠀⢸⣿⡿⠀⠀⢀⠀⠀⠀⢀⣤⣶⣿⠿⠛⠁⠀
# ⢧⣹⣶⣾⣿⡄⠀⠀⠸⡟⠋⠘⡜⡆⠀⠀⢻⣿⡇⠀⠀⢸⡀⣿⠀⠀⢸⣿⡿⡇⠀⠀⢸⣿⡇⠀⠀⢸⡿⡆⠀⠀⠀⣾⣿⠃⠀⠀⣾⡇⠀⠀⠈⡟⠉⠀⠀⠀⠀⠀
# ⠘⣿⡿⠿⢿⣧⠀⠀⠀⢳⡀⠀⣇⢱⠀⠀⠈⣿⣷⠀⣀⣸⣷⣿⣤⣤⣼⠋⣇⣹⣶⣶⣾⣿⡿⢲⣶⣾⡇⣿⣤⣀⣀⣿⡏⠀⠀⣼⡏⢧⠀⠀⠀⣇⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠸⡞⣇⠀⠀⠀⢧⠀⢸⣈⣷⣶⣶⣿⣿⣿⣿⣿⣿⣿⣽⣿⡏⢀⡼⠟⠛⠻⢿⡿⠿⠿⣿⣁⣿⣿⣿⣿⣿⣿⣿⣶⣴⢿⠁⢸⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⢹⣼⣦⣤⣶⣿⠁⣀⣿⠿⠿⣿⣫⣿⠉⠁⠀⠀⠀⡏⠀⣴⠏⠀⠀⠀⠀⠀⠹⣆⠀⢠⣿⠀⠀⠀⢈⠟⢻⡿⠿⣅⣘⡆⣸⣇⠀⠀⢸⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠻⠿⠿⠛⠃⢠⣿⣷⣄⠀⠈⠙⠋⠀⠀⠀⠀⣸⢁⡾⠁⠀⠀⣠⣤⡀⠀⠀⠸⣤⡞⡇⠀⠀⠀⢸⣰⣿⠃⠀⠀⢹⣿⣿⣿⣿⣦⣼⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⢿⣿⣿⣷⣄⠀⠀⠀⠀⠀⠀⣿⣾⠇⠀⠀⣸⣿⣿⢿⠀⠀⠀⣿⢁⡇⠀⠀⢀⣿⣿⡏⠀⠀⠀⡼⠀⢙⣿⠛⠻⣏⡀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣿⣿⣷⠀⠀⠀⠀⢸⡿⡿⠀⠀⠀⡏⢹⠟⡟⠀⠀⠀⡿⢸⠀⠀⠀⢸⣿⡿⠀⠀⠀⢠⠇⡰⢋⡏⠀⠀⠀⢙⡆⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⡿⡿⠀⠀⠀⠀⣸⡇⡇⠀⠀⠀⠻⠾⠞⠁⠀⠀⢀⡇⡏⠀⠀⠀⢸⣿⠃⠀⠀⠀⡼⣰⠃⡞⠀⠀⠀⠀⡾⠁⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⡇⡇⠀⠀⠀⠀⣿⣇⣷⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⣃⡇⠀⠀⠀⠀⠀⠀⠀⠀⣼⣷⠃⣼⡀⠀⠀⢀⡞⠁⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⢸⠃⠀⠀⠀⢀⡇⢿⣿⣧⣀⠀⠀⠀⠀⠀⣠⣾⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⣽⣿⣷⣤⡞⠁⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣼⣤⣶⣶⣶⡿⠁⠈⢿⣿⣿⣿⣿⣿⣿⣿⠿⠃⢸⣿⣿⣷⣤⣄⣀⣀⣤⣾⣏⣤⡟⠁⠀⠈⠻⡍⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠿⠿⠿⠟⠛⠁⠀⠀⠀⠉⠛⠛⠛⠛⠉⠁⠀⠀⠀⠙⠿⢿⣿⣿⡿⠿⠋⢀⣿⣿⣧⡀⠀⠀⣠⡇⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢿⣿⣿⣿⣿⠟⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
